# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:\\Users\\darsh\\Downloads\\StudentDataset.csv")

# %%
data
# Out:
#       Serial No         Name                                      University  \
# 0             1      Ami0603               Arizona State University, Arizona
# 1             2      Sonajan               Arizona State University, Arizona
# 2             3    saniya264               Arizona State University, Arizona
# 3             4    Abhiraj29               Arizona State University, Arizona
# 4             5   apekshak95               Arizona State University, Arizona
# ...         ...          ...                                             ...
# 2111       2941   mandar1991  Worcester Polytechnic Institute, Massachusetts
# 2112       2942     Shivanim  Worcester Polytechnic Institute, Massachusetts
# 2113       2944   skondepudi  Worcester Polytechnic Institute, Massachusetts
# 2114       2948  Ankurchintu  Worcester Polytechnic Institute, Massachusetts
# 2115       2949     jazz1085  Worcester Polytechnic Institute, Massachusetts
#
# ...

# %%
from sklearn import preprocessing

# %%
data[['University Name','State']]=data['University'].str.split(',' ,expand=True)

# %%
data
# Out:
#       Serial No         Name                                      University  \
# 0             1      Ami0603               Arizona State University, Arizona
# 1             2      Sonajan               Arizona State University, Arizona
# 2             3    saniya264               Arizona State University, Arizona
# 3             4    Abhiraj29               Arizona State University, Arizona
# 4             5   apekshak95               Arizona State University, Arizona
# ...         ...          ...                                             ...
# 2111       2941   mandar1991  Worcester Polytechnic Institute, Massachusetts
# 2112       2942     Shivanim  Worcester Polytechnic Institute, Massachusetts
# 2113       2944   skondepudi  Worcester Polytechnic Institute, Massachusetts
# 2114       2948  Ankurchintu  Worcester Polytechnic Institute, Massachusetts
# 2115       2949     jazz1085  Worcester Polytechnic Institute, Massachusetts
#
# ...

# %%
data1=data.drop(['University'],axis=1)

# %%
data1 #data2=data1([''],[])
# Out:
#       Serial No         Name                         Course          Year  \
# 0             1      Ami0603  Management Information System    Fall 2018
# 1             2      Sonajan  Management Information System    Fall 2018
# 2             3    saniya264  Management Information System    Fall 2018
# 3             4    Abhiraj29  Management Information System    Fall 2018
# 4             5   apekshak95  Management Information System    Fall 2018
# ...         ...          ...                            ...           ...
# 2111       2941   mandar1991  Management Information System  Spring 2018
# 2112       2942     Shivanim  Management Information System    Fall 2018
# 2113       2944   skondepudi  Management Information System    Fall 2018
# 2114       2948  Ankurchintu  Management Information System    Fall 2019
# 2115       2949     jazz1085  Management Information System    Fall 2018
#
#           Status GRE_SCORE  Eng_test  Test_score Undergrad_score  work_ex  \
# ...

# %%
data1.to_csv('C:\\Users\\darsh\\Downloads\\Student_DataNormalized.csv')
